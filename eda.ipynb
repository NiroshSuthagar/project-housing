# %% [markdown]
# # Working Out Schema

# %%
# !pip install tableschema
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install psycopg2-binary
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv

# %%
root_folder = 'data-epc'
file_type = '.csv'

data_dump = []

# %%
def load_file(path):
    if path.endswith('.csv'):
        return pd.read_csv(path)
    return None

# %%
for root, dirs, files in os.walk(root_folder): 
    for file in files: 
        if file.lower().endswith(file_type) and file.lower().startswith('certificates'):
            file_path = os.path.join(root,file)
            print(f'Loading: {file_path}')

            df = load_file(file_path)
            df['source_file'] = file_path
            data_dump.append(df)
# Out:
# Loading: data-epc/domestic-E06000041-Wokingham/certificates.csv
# /var/folders/c3/1g8s1kz57t5fy4f84jm4vjwr0000gn/T/ipykernel_90282/1715873210.py:3: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path)
# Loading: data-epc/domestic-E06000037-West-Berkshire/certificates copy.csv
# /var/folders/c3/1g8s1kz57t5fy4f84jm4vjwr0000gn/T/ipykernel_90282/1715873210.py:3: DtypeWarning: Columns (15,34,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path)
# Loading: data-epc/domestic-E06000039-Slough/certificates.csv
# /var/folders/c3/1g8s1kz57t5fy4f84jm4vjwr0000gn/T/ipykernel_90282/1715873210.py:3: DtypeWarning: Columns (15,34,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path)
# Loading: data-epc/domestic-E07000005-Chiltern/certificates.csv
# Loading: data-epc/domestic-E07000213-Spelthorne/certificates.csv
# ...

# %%
# Combining the datasets as they have the same schema
combined_df = pd.concat(data_dump, ignore_index=True, sort=False)
combined_df.head()
# Out:
#                               LMK_KEY           ADDRESS1          ADDRESS2  \
# 0   509075769602010070514280374700258      Oldbury Court       Houston Way
# 1   825484589922012081523401030158582   32, Jersey Drive          Winnersh
# 2   308522336512020052719593725200865  5, Mount Pleasant               NaN
# 3  1400255992812016022517164196949049  10, Grazeley Road  Three Mile Cross
# 4   532780989652010082610135392200777   2, Chilcombe Way      Lower Earley
#
#   ADDRESS3  POSTCODE  BUILDING_REFERENCE_NUMBER CURRENT_ENERGY_RATING  \
# 0      NaN  RG45 6BY                 6689367768                     D
# 1      NaN  RG41 5FR                 8309890078                     C
# 2      NaN  RG41 2YG                 8588653668                     E
# 3      NaN   RG7 1BJ                  970261478                     B
# 4      NaN   RG6 3DA                 7744929768                     D
#
#   POTENTIAL_ENERGY_RATING  CURRENT_ENERGY_EFFICIENCY  \
# ...

# %%
load_dotenv()
password = os.getenv('db_pass')
database_name = os.getenv('db_name')

# Creating an engine to write to PostgresSQL
engine = create_engine(f'postgresql+psycopg2://postgres:{password}@localhost:5432/{database_name}')

# %%
'''
# Writing to SQL
combined_df.to_sql(
    'epc_certificates',
    engine,
    if_exists='replace',
    index=False
)
'''
# Out:
# "\n# Writing to SQL\ncombined_df.to_sql(\n    'epc_certificates',\n    engine,\n    if_exists='replace',\n    index=False\n)\n"

# %%
combined_df.size
# Out:
# 134942076

# %%
valid_postcodes = ('HP8', 'SL9', 'SL1', 'SL2', 'SL3', 'SL0', 'SL6', 'SL7', 'HP9', 'HP10', 'SL4', 'HP11', 'HP12', 'HP13')

valid_EPC = combined_df[combined_df['POSTCODE'].str.startswith(valid_postcodes)]

valid_EPC.shape
# Out:
# (222359, 94)

# %%
valid_EPC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222359 entries, 144134 to 1329331
# Data columns (total 94 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   LMK_KEY                        222359 non-null  object
#  1   ADDRESS1                       222359 non-null  object
#  2   ADDRESS2                       101959 non-null  object
#  3   ADDRESS3                       25425 non-null   object
#  4   POSTCODE                       222359 non-null  object
#  5   BUILDING_REFERENCE_NUMBER      222359 non-null  int64
#  6   CURRENT_ENERGY_RATING          222359 non-null  object
#  7   POTENTIAL_ENERGY_RATING        222359 non-null  object
#  8   CURRENT_ENERGY_EFFICIENCY      222359 non-null  int64
#  9   POTENTIAL_ENERGY_EFFICIENCY    222359 non-null  int64
#  10  PROPERTY_TYPE                  222359 non-null  object
#  11  BUILT_FORM                     222342 non-null  object
# ...

# %%
summary = valid_EPC.isna().sum().sort_values(ascending=False)

# %%
summary.head(n=50)
# Out:
# SHEATING_ENERGY_EFF             222359
# SHEATING_ENV_EFF                222359
# FLOOR_ENV_EFF                   208028
# FLAT_STOREY_COUNT               206103
# ADDRESS3                        196934
# UNHEATED_CORRIDOR_LENGTH        187998
# FLOOR_ENERGY_EFF                154171
# COUNTY                          152545
# LOW_ENERGY_FIXED_LIGHT_COUNT    151067
# SECONDHEAT_DESCRIPTION          149401
# FLAT_TOP_STOREY                 145774
# ADDRESS2                        120400
# FLOOR_HEIGHT                    102351
# FIXED_LIGHTING_OUTLETS_COUNT     89344
# MAIN_HEATING_CONTROLS            84848
# PHOTO_SUPPLY                     80521
# SOLAR_WATER_HEATING_FLAG         74618
# ROOF_ENERGY_EFF                  48436
# ROOF_ENV_EFF                     48436
# HEAT_LOSS_CORRIDOR               46726
# FLOOR_LEVEL                      40176
# MAINS_GAS_FLAG                   26079
# EXTENSION_COUNT                  25817
# NUMBER_HABITABLE_ROOMS           25817
# ...

# %%
valid_EPC.shape
# Out:
# (222359, 94)

# %% [markdown]
# # Land Registry Load

# %%
def load_folder_csvs(filepath, file_type='.csv', data_dump=[]):
    root_folder = filepath
    
    for root, dirs, files in os.walk(root_folder): 
        for file in files: 
            if file.lower().endswith(file_type):
                file_path = os.path.join(root,file)
                print(f'Loading: {file_path}')

                df = load_file(file_path)
                df['source_file'] = file_path
                data_dump.append(df)
    return data_dump

# %%
land_registry = load_folder_csvs(filepath='./data-land_registry')
# Out:
# Loading: ./data-land_registry/HP13-march2020-to-nov2025.csv
# Loading: ./data-land_registry/SL2-march2020-to-nov2025.csv
# Loading: ./data-land_registry/SL6-march2020-to-nov2025.csv
# Loading: ./data-land_registry/HP12-march2020-to-nov2025.csv
# Loading: ./data-land_registry/SL7-march2020-to-nov2025.csv
# Loading: ./data-land_registry/SL3-march2020-to-nov2025.csv
# Loading: ./data-land_registry/SL1-march2020-to-nov2025.csv.csv
# Loading: ./data-land_registry/HP10-march2020-to-nov2025.csv
# Loading: ./data-land_registry/HP9-march2020-to-nov2025.csv
# Loading: ./data-land_registry/HP8-march2020-to-nov2025.csv
# Loading: ./data-land_registry/SL4-march2020-to-nov2025.csv
# Loading: ./data-land_registry/SL0-march2020-to-nov2025.csv
# Loading: ./data-land_registry/HP11-march2020-to-nov2025.csv
# Loading: ./data-land_registry/SL9-march2020-to-nov2025.csv.csv

# %%
type(land_registry)
# Out:
# list

# %%
land_registry[0]
# Out:
#                                  unique_id  price_paid   deed_date  postcode  \
# 0     E2D14905-119C-4C2D-E053-6B04A8C0422B      582000  2022-06-06  HP13 5AA
# 1     2ACACE8C-96D3-295E-E063-4804A8C0B0EB      655000  2024-12-12  HP13 5AA
# 2     D4D42645-4622-27F6-E053-6C04A8C0A572      560000  2021-10-28  HP13 5AA
# 3     34222871-FD7A-4D2B-E063-4704A8C07853      375000  2025-03-31  HP13 5AB
# 4     F5E8B080-E8B1-3A13-E053-6C04A8C060B7      440000  2023-01-20  HP13 5AD
# ...                                    ...         ...         ...       ...
# 2163  D22473F4-E36F-7B40-E053-6C04A8C0A630      335000  2021-09-30  HP13 7YE
# 2164  F3B6C197-C135-6E40-E053-6C04A8C0B3B4      360000  2022-07-15  HP13 7YE
# 2165  CD5A9DCB-8C0E-310A-E053-6C04A8C00A1F      305000  2021-03-26  HP13 7YE
# 2166  DBA933F9-00A9-669D-E053-6B04A8C0AD56      285000  2021-12-22  HP13 7YE
# 2167  D93B27B0-4DCC-3100-E053-6C04A8C08887      335000  2021-09-24  HP13 7YT
#
# ...

# %%
def concat_list_of_df(list_item=land_registry):
    try:
        if len(list_item) == 1:
            return list_item[0].copy()
        
        combined = pd.concat(list_item, ignore_index=True, axis=0)
        return combined
    
    except Exception as e:
        print(f'Combining dataframes errored with: {e}')
        
LR_combined = concat_list_of_df()

# %%
LR_combined.head()
# Out:
#                               unique_id  price_paid   deed_date  postcode  \
# 0  E2D14905-119C-4C2D-E053-6B04A8C0422B      582000  2022-06-06  HP13 5AA
# 1  2ACACE8C-96D3-295E-E063-4804A8C0B0EB      655000  2024-12-12  HP13 5AA
# 2  D4D42645-4622-27F6-E053-6C04A8C0A572      560000  2021-10-28  HP13 5AA
# 3  34222871-FD7A-4D2B-E063-4704A8C07853      375000  2025-03-31  HP13 5AB
# 4  F5E8B080-E8B1-3A13-E053-6C04A8C060B7      440000  2023-01-20  HP13 5AD
#
#   property_type new_build estate_type saon paon         street locality  \
# 0             S         N           F  NaN   49  AMERSHAM ROAD      NaN
# 1             S         N           F  NaN   67  AMERSHAM ROAD      NaN
# 2             S         N           F  NaN   67  AMERSHAM ROAD      NaN
# 3             T         N           F  NaN  134  AMERSHAM ROAD      NaN
# 4             S         N           F  NaN  145  AMERSHAM ROAD      NaN
#
#            town         district           county transaction_category  \
# ...

# %%
LR_combined.size
# Out:
# 379933

# %% [markdown]
# # Combining Datasets

# %%
valid_EPC.head(n=1)
# Out:
#                                   LMK_KEY           ADDRESS1 ADDRESS2  \
# 144134  210776721852020070208271224000054  48, Stanhope Road      NaN
#
#        ADDRESS3 POSTCODE  BUILDING_REFERENCE_NUMBER CURRENT_ENERGY_RATING  \
# 144134      NaN  SL1 6JS                  487146568                     D
#
#        POTENTIAL_ENERGY_RATING  CURRENT_ENERGY_EFFICIENCY  \
# 144134                       B                         56
#
#         POTENTIAL_ENERGY_EFFICIENCY  ... POSTTOWN  \
# 144134                           84  ...   SLOUGH
#
#                CONSTRUCTION_AGE_BAND   LODGEMENT_DATETIME            TENURE  \
# 144134  England and Wales: 1930-1949  2020-07-02 08:27:12  rental (private)
#
#        FIXED_LIGHTING_OUTLETS_COUNT LOW_ENERGY_FIXED_LIGHT_COUNT  \
# 144134                          NaN                          NaN
#
#                 UPRN      UPRN_SOURCE  REPORT_TYPE  \
# 144134  1.000803e+11  Address Matched          100
#
# ...

# %%
LR_combined.head(n=1)
# Out:
#                               unique_id  price_paid   deed_date  postcode  \
# 0  E2D14905-119C-4C2D-E053-6B04A8C0422B      582000  2022-06-06  HP13 5AA
#
#   property_type new_build estate_type saon paon         street locality  \
# 0             S         N           F  NaN   49  AMERSHAM ROAD      NaN
#
#            town         district           county transaction_category  \
# 0  HIGH WYCOMBE  BUCKINGHAMSHIRE  BUCKINGHAMSHIRE                    A
#
#                                      linked_data_uri  \
# 0  http://landregistry.data.gov.uk/data/ppi/trans...
#
#                                          source_file
# 0  ./data-land_registry/HP13-march2020-to-nov2025...

# %%
LR_combined.columns
# Out:
# Index(['unique_id', 'price_paid', 'deed_date', 'postcode', 'property_type',
#        'new_build', 'estate_type', 'saon', 'paon', 'street', 'locality',
#        'town', 'district', 'county', 'transaction_category', 'linked_data_uri',
#        'source_file'],
#       dtype='object')

# %% [markdown]
# ! Looks like the Land Registry data does not have an address field so we need to make one.

# %%
valid_EPC.head()
# Out:
#                                    LMK_KEY                    ADDRESS1  \
# 144134   210776721852020070208271224000054           48, Stanhope Road
# 144135  1326681509222015052912541786218345       Flat 112 West Central
# 144136   962080069842014120417254410040148  39a, Hencroft Street South
# 144137  1132980469202014051311353821240768               20, Thorndike
# 144138   225287962132009020314541192068601             5, Elmwood Road
#
#               ADDRESS2 ADDRESS3 POSTCODE  BUILDING_REFERENCE_NUMBER  \
# 144134             NaN      NaN  SL1 6JS                  487146568
# 144135  1a, Stoke Road      NaN  SL2 5PF                 4881046378
# 144136             NaN      NaN  SL1 1RF                 3825360178
# 144137             NaN      NaN  SL2 1SR                 9294862278
# 144138             NaN      NaN  SL2 5QQ                 6162637568
#
#        CURRENT_ENERGY_RATING POTENTIAL_ENERGY_RATING  \
# 144134                     D                       B
# ...

# %%
LR_combined.head()
# Out:
#                               unique_id  price_paid   deed_date  postcode  \
# 0  E2D14905-119C-4C2D-E053-6B04A8C0422B      582000  2022-06-06  HP13 5AA
# 1  2ACACE8C-96D3-295E-E063-4804A8C0B0EB      655000  2024-12-12  HP13 5AA
# 2  D4D42645-4622-27F6-E053-6C04A8C0A572      560000  2021-10-28  HP13 5AA
# 3  34222871-FD7A-4D2B-E063-4704A8C07853      375000  2025-03-31  HP13 5AB
# 4  F5E8B080-E8B1-3A13-E053-6C04A8C060B7      440000  2023-01-20  HP13 5AD
#
#   property_type new_build estate_type saon paon         street locality  \
# 0             S         N           F  NaN   49  AMERSHAM ROAD      NaN
# 1             S         N           F  NaN   67  AMERSHAM ROAD      NaN
# 2             S         N           F  NaN   67  AMERSHAM ROAD      NaN
# 3             T         N           F  NaN  134  AMERSHAM ROAD      NaN
# 4             S         N           F  NaN  145  AMERSHAM ROAD      NaN
#
#            town         district           county transaction_category  \
# ...

# %%
valid_EPC.columns
# Out:
# Index(['LMK_KEY', 'ADDRESS1', 'ADDRESS2', 'ADDRESS3', 'POSTCODE',
#        'BUILDING_REFERENCE_NUMBER', 'CURRENT_ENERGY_RATING',
#        'POTENTIAL_ENERGY_RATING', 'CURRENT_ENERGY_EFFICIENCY',
#        'POTENTIAL_ENERGY_EFFICIENCY', 'PROPERTY_TYPE', 'BUILT_FORM',
#        'INSPECTION_DATE', 'LOCAL_AUTHORITY', 'CONSTITUENCY', 'COUNTY',
#        'LODGEMENT_DATE', 'TRANSACTION_TYPE', 'ENVIRONMENT_IMPACT_CURRENT',
#        'ENVIRONMENT_IMPACT_POTENTIAL', 'ENERGY_CONSUMPTION_CURRENT',
#        'ENERGY_CONSUMPTION_POTENTIAL', 'CO2_EMISSIONS_CURRENT',
#        'CO2_EMISS_CURR_PER_FLOOR_AREA', 'CO2_EMISSIONS_POTENTIAL',
#        'LIGHTING_COST_CURRENT', 'LIGHTING_COST_POTENTIAL',
#        'HEATING_COST_CURRENT', 'HEATING_COST_POTENTIAL',
#        'HOT_WATER_COST_CURRENT', 'HOT_WATER_COST_POTENTIAL',
#        'TOTAL_FLOOR_AREA', 'ENERGY_TARIFF', 'MAINS_GAS_FLAG', 'FLOOR_LEVEL',
#        'FLAT_TOP_STOREY', 'FLAT_STOREY_COUNT', 'MAIN_HEATING_CONTROLS',
# ...

# %%
LR_combined.columns
# Out:
# Index(['unique_id', 'price_paid', 'deed_date', 'postcode', 'property_type',
#        'new_build', 'estate_type', 'saon', 'paon', 'street', 'locality',
#        'town', 'district', 'county', 'transaction_category', 'linked_data_uri',
#        'source_file'],
#       dtype='object')

# %%
valid_EPC['ADDRESS'].head()
# Out:
# 144134                        48, Stanhope Road
# 144135    Flat 112 West Central, 1a, Stoke Road
# 144136               39a, Hencroft Street South
# 144137                            20, Thorndike
# 144138                          5, Elmwood Road
# Name: ADDRESS, dtype: object

# %%
LR_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22349 entries, 0 to 22348
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unique_id             22349 non-null  object
#  1   price_paid            22349 non-null  int64
#  2   deed_date             22349 non-null  object
#  3   postcode              22349 non-null  object
#  4   property_type         22349 non-null  object
#  5   new_build             22349 non-null  object
#  6   estate_type           22349 non-null  object
#  7   saon                  484 non-null    object
#  8   paon                  22349 non-null  object
#  9   street                22330 non-null  object
#  10  locality              6417 non-null   object
#  11  town                  22349 non-null  object
#  12  district              22349 non-null  object
#  13  county                22349 non-null  object
#  14  transaction_category  22349 non-null  object
# ...

# %%
def colToStr(list_of_cols,  df):
    df[list_of_cols]= df[list_of_cols].astype(str)

# %%
colToStr(['paon','street','postcode'], LR_combined)

# %%
LR_combined['combined_address'] = LR_combined[['paon','street','postcode']].agg(' '.join, axis=1)
LR_combined.head()
# Out:
#                               unique_id  price_paid   deed_date  postcode  \
# 0  E2D14905-119C-4C2D-E053-6B04A8C0422B      582000  2022-06-06  HP13 5AA
# 1  2ACACE8C-96D3-295E-E063-4804A8C0B0EB      655000  2024-12-12  HP13 5AA
# 2  D4D42645-4622-27F6-E053-6C04A8C0A572      560000  2021-10-28  HP13 5AA
# 3  34222871-FD7A-4D2B-E063-4704A8C07853      375000  2025-03-31  HP13 5AB
# 4  F5E8B080-E8B1-3A13-E053-6C04A8C060B7      440000  2023-01-20  HP13 5AD
#
#   property_type new_build estate_type saon paon         street locality  \
# 0             S         N           F  NaN   49  AMERSHAM ROAD      NaN
# 1             S         N           F  NaN   67  AMERSHAM ROAD      NaN
# 2             S         N           F  NaN   67  AMERSHAM ROAD      NaN
# 3             T         N           F  NaN  134  AMERSHAM ROAD      NaN
# 4             S         N           F  NaN  145  AMERSHAM ROAD      NaN
#
#            town         district           county transaction_category  \
# ...

# %%
LR_address_cols = LR_combined[['postcode', 'saon','paon', 'street','locality', 'town','district','county']]
LR_address_cols.head()
# Out:
#    postcode saon paon         street locality          town         district  \
# 0  HP13 5AA  NaN   49  AMERSHAM ROAD      NaN  HIGH WYCOMBE  BUCKINGHAMSHIRE
# 1  HP13 5AA  NaN   67  AMERSHAM ROAD      NaN  HIGH WYCOMBE  BUCKINGHAMSHIRE
# 2  HP13 5AA  NaN   67  AMERSHAM ROAD      NaN  HIGH WYCOMBE  BUCKINGHAMSHIRE
# 3  HP13 5AB  NaN  134  AMERSHAM ROAD      NaN  HIGH WYCOMBE  BUCKINGHAMSHIRE
# 4  HP13 5AD  NaN  145  AMERSHAM ROAD      NaN  HIGH WYCOMBE  BUCKINGHAMSHIRE
#
#             county
# 0  BUCKINGHAMSHIRE
# 1  BUCKINGHAMSHIRE
# 2  BUCKINGHAMSHIRE
# 3  BUCKINGHAMSHIRE
# 4  BUCKINGHAMSHIRE

# %%
valid_EPC.columns
# Out:
# Index(['LMK_KEY', 'ADDRESS1', 'ADDRESS2', 'ADDRESS3', 'POSTCODE',
#        'BUILDING_REFERENCE_NUMBER', 'CURRENT_ENERGY_RATING',
#        'POTENTIAL_ENERGY_RATING', 'CURRENT_ENERGY_EFFICIENCY',
#        'POTENTIAL_ENERGY_EFFICIENCY', 'PROPERTY_TYPE', 'BUILT_FORM',
#        'INSPECTION_DATE', 'LOCAL_AUTHORITY', 'CONSTITUENCY', 'COUNTY',
#        'LODGEMENT_DATE', 'TRANSACTION_TYPE', 'ENVIRONMENT_IMPACT_CURRENT',
#        'ENVIRONMENT_IMPACT_POTENTIAL', 'ENERGY_CONSUMPTION_CURRENT',
#        'ENERGY_CONSUMPTION_POTENTIAL', 'CO2_EMISSIONS_CURRENT',
#        'CO2_EMISS_CURR_PER_FLOOR_AREA', 'CO2_EMISSIONS_POTENTIAL',
#        'LIGHTING_COST_CURRENT', 'LIGHTING_COST_POTENTIAL',
#        'HEATING_COST_CURRENT', 'HEATING_COST_POTENTIAL',
#        'HOT_WATER_COST_CURRENT', 'HOT_WATER_COST_POTENTIAL',
#        'TOTAL_FLOOR_AREA', 'ENERGY_TARIFF', 'MAINS_GAS_FLAG', 'FLOOR_LEVEL',
#        'FLAT_TOP_STOREY', 'FLAT_STOREY_COUNT', 'MAIN_HEATING_CONTROLS',
# ...

# %%
valid_EPC[['ADDRESS', 'ADDRESS1', 'ADDRESS2', 'ADDRESS3']].head()
# Out:
#                                       ADDRESS                    ADDRESS1  \
# 144134                      48, Stanhope Road           48, Stanhope Road
# 144135  Flat 112 West Central, 1a, Stoke Road       Flat 112 West Central
# 144136             39a, Hencroft Street South  39a, Hencroft Street South
# 144137                          20, Thorndike               20, Thorndike
# 144138                        5, Elmwood Road             5, Elmwood Road
#
#               ADDRESS2 ADDRESS3
# 144134             NaN      NaN
# 144135  1a, Stoke Road      NaN
# 144136             NaN      NaN
# 144137             NaN      NaN
# 144138             NaN      NaN

# %%
valid_EPC.loc[valid_EPC['ADDRESS']!= valid_EPC['ADDRESS1'], ['ADDRESS','ADDRESS1', 'ADDRESS2','ADDRESS3']]
# Out:
#                                                 ADDRESS  \
# 144135            Flat 112 West Central, 1a, Stoke Road
# 144141                 4 Arlington Court, Hawtrey Close
# 144144          Flat 65 The Pines, Forest Close, Wexham
# 144147                          Flat 6, 27, Grays Place
# 144148                      36 The Foyer, 52 Stoke Road
# ...                                                 ...
# 1303430      High Trees, Shire Lane, Chalfont St. Peter
# 1304184                     Nathans Barn, Chalfont Road
# 1308069  Crooked Billet, Shire Lane, Chalfont St. Peter
# 1315613   Court Cottage, Shire Lane, Chalfont St. Peter
# 1329331                   Flat 1, Hill View, Shire Lane
#
#                       ADDRESS1         ADDRESS2            ADDRESS3
# 144135   Flat 112 West Central   1a, Stoke Road                 NaN
# 144141       4 Arlington Court    Hawtrey Close                 NaN
# 144144       Flat 65 The Pines     Forest Close              Wexham
# ...

# %%
valid_EPC.ADDRESS2.fillna('')
# Out:
# 144134
# 144135     1a, Stoke Road
# 144136
# 144137
# 144138
#                 ...
# 1303430        Shire Lane
# 1304184     Chalfont Road
# 1308069        Shire Lane
# 1315613        Shire Lane
# 1329331        Hill View
# Name: ADDRESS2, Length: 222359, dtype: object

# %%
valid_EPC['combined_address'] = valid_EPC[['ADDRESS', 'POSTCODE']].agg(' '.join, axis=1)
valid_EPC.head()
# Out:
# /var/folders/c3/1g8s1kz57t5fy4f84jm4vjwr0000gn/T/ipykernel_90282/947810106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_EPC['combined_address'] = valid_EPC[['ADDRESS', 'POSTCODE']].agg(' '.join, axis=1)
#                                    LMK_KEY                    ADDRESS1  \
# 144134   210776721852020070208271224000054           48, Stanhope Road
# 144135  1326681509222015052912541786218345       Flat 112 West Central
# 144136   962080069842014120417254410040148  39a, Hencroft Street South
# 144137  1132980469202014051311353821240768               20, Thorndike
# 144138   225287962132009020314541192068601             5, Elmwood Road
#
#               ADDRESS2 ADDRESS3 POSTCODE  BUILDING_REFERENCE_NUMBER  \
# ...

# %%
LR_combined['ADDRESS_V1'] = LR_combined[['paon','street','postcode']].agg(' '.join, axis=1)
LR_combined.head()

# %%
# Attempting a merge now the combined columns are done

merged = LR_combined.merge(valid_EPC,on='combined_address', how='left',indicator=True) #indicator to show merge status! 

print(merged['_merge'].value_counts())
# Out:
# _merge
# left_only     21786
# both            566
# right_only        0
# Name: count, dtype: int64

# %%
# !pip install rapidfuzz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 9.5 MB/s  0:00:00
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from rapidfuzz import fuzz, process

# %%
LR_combined['combined_address'] = LR_combined['combined_address'].str.lower()
valid_EPC['combined_address'] = valid_EPC['combined_address'].str.lower()
# Out:
# /var/folders/c3/1g8s1kz57t5fy4f84jm4vjwr0000gn/T/ipykernel_90282/1896803352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_EPC['combined_address'] = valid_EPC['combined_address'].str.lower()

# %%
right_addresses = valid_EPC['combined_address'].unique().tolist()

# Fuzzy Match operation
def fuzzy_merge_row(address, threshold=85):
    match = process.extractOne(address, right_addresses, scorer=fuzz.ratio)
    if match and match[1] >= threshold:
        return match[0]
    return None

LR_combined['fuzzy_match'] = LR_combined.apply(fuzzy_merge_row)

# Now merging 

result = LR_combined.merge(valid_EPC, left_on='fuzzy_match',right_on='combined_address',how='left', indicator=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[138], line 10
#       7         return match[0]
#       8     return None
# ---> 10 LR_combined['fuzzy_match'] = LR_combined.apply(fuzzy_merge_row)
#      12 # Now merging
#      14 result = LR_combined.merge(valid_EPC, left_on='fuzzy_match',right_on='combined_address',how='left', indicator=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
# ...

# %%
right_addresses
# Out:
# ['48 Stanhope Road SL1 6JS',
#  'Flat 112 West Central 1a Stoke Road SL2 5PF',
#  '39a Hencroft Street South SL1 1RF',
#  '20 Thorndike SL2 1SR',
#  '5 Elmwood Road SL2 5QQ',
#  '6 Lodge Close SL1 2XX',
#  '46 Worcester Gardens SL1 2QB',
#  '4 Arlington Court Hawtrey Close SL1 1AN',
#  '10 St. Elmo Crescent SL2 1NN',
#  '38 Salt Hill Way SL1 3TR',
#  'Flat 65 The Pines Forest Close Wexham SL2 4FJ',
#  '37 Gilmore Close SL3 7BD',
#  '106 Botham Drive SL1 2LZ',
#  'Flat 6 27 Grays Place SL2 5JQ',
#  '36 The Foyer 52 Stoke Road SL2 5AW',
#  '32 Leith Close SL1 1UT',
#  '76 Burnham Lane SL1 6LS',
#  '42 Windermere Way SL1 6EL',
#  '6 Moore Close SL1 9HJ',
#  '12 Lundy Court Bower Way SL1 5HS',
#  '7 Vicarage Way Colnbrook SL3 0RA',
#  '62 Cornwall Avenue SL2 1AZ',
#  '26 Chatfield SL2 1SF',
#  '34 Worcester Gardens SL1 2QD',
#  'Flat 7 D T C House 29 Grays Place SL2 5AF',
#  '29 Richards Way SL1 5EU',
#  '124 Parlaunt Road SL3 8AZ',
#  '49 Lower Cippenham Lane SL1 5DG',
# ...

# %%
LR_combined['combined_address'] = LR_combined['combined_address'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)

LR_combined['combined_address'] = LR_combined['combined_address'].str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
LR_combined.combined_address
# Out:
# 0             49 AMERSHAM ROAD HP13 5AA
# 1             67 AMERSHAM ROAD HP13 5AA
# 2             67 AMERSHAM ROAD HP13 5AA
# 3            134 AMERSHAM ROAD HP13 5AB
# 4            145 AMERSHAM ROAD HP13 5AD
#                       ...
# 22344    GLENTORP HALFACRE HILL SL9 9UD
# 22345            1 LINDEN DRIVE SL9 9UP
# 22346            5 LINDEN DRIVE SL9 9UP
# 22347           11 LINDEN DRIVE SL9 9UP
# 22348           12 LINDEN DRIVE SL9 9UP
# Name: combined_address, Length: 22349, dtype: object

# %%
LR_combined.shape
# Out:
# (22349, 20)

# %%
valid_EPC['combined_address'] = valid_EPC['combined_address'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)

#
valid_EPC['combined_address'] = valid_EPC['combined_address'].str.replace(r'\s+', ' ', regex=True).str.strip()
# Out:
# /var/folders/c3/1g8s1kz57t5fy4f84jm4vjwr0000gn/T/ipykernel_90282/201423290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_EPC['combined_address'] = valid_EPC['combined_address'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)
# /var/folders/c3/1g8s1kz57t5fy4f84jm4vjwr0000gn/T/ipykernel_90282/201423290.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_EPC['combined_address'] = valid_EPC['combined_address'].str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
right_addresses = valid_EPC['combined_address'].unique().tolist()

# Fuzzy Match operation
def fuzzy_merge_row(address, threshold=80):
    match = process.extractOne(address, right_addresses, scorer=fuzz.ratio)
    if match and match[1] >= threshold:
        return match[0], match[1] # Returning the address and score
    return None

LR_combined[['fuzzy_match', 'match_confidence']] = LR_combined['combined_address'].apply(
    lambda x: pd.Series(fuzzy_merge_row(x))
    )

# Now merging 

result = LR_combined.merge(valid_EPC, left_on='fuzzy_match',right_on='combined_address',how='left', indicator=True)

# %%
result['_merge'].value_counts()
# Out:
# _merge
# both          28815
# left_only      2068
# right_only        0
# Name: count, dtype: int64

# %%
result.loc[result['match_confidence']<90].shape
# Out:
# (5388, 117)

# %%
result.loc[result['match_confidence']<85].to_csv('low_conf_match.csv')

# %%
# Checking EPC data for a record
valid_EPC['combined_address'].loc[valid_EPC['POSTCODE'] == 'HP13 5DA']
# Out:
# 478719    14 park view crescent coates lane hp13 5da
# 479202     8 park view crescent coates lane hp13 5da
# 483225    17 park view crescent coates lane hp13 5da
# 484093    15 park view crescent coates lane hp13 5da
# 487321     5 park view crescent coates lane hp13 5da
# 488076     5 park view crescent coates lane hp13 5da
# 492416     4 park view crescent coates lane hp13 5da
# 498644    12 park view crescent coates lane hp13 5da
# 499909     2 park view crescent coates lane hp13 5da
# 503465    16 park view crescent coates lane hp13 5da
# 509449     7 park view crescent coates lane hp13 5da
# 511496    11 park view crescent coates lane hp13 5da
# 512287     6 park view crescent coates lane hp13 5da
# 512736     1 park view crescent coates lane hp13 5da
# 515122    10 park view crescent coates lane hp13 5da
# 517947     9 park view crescent coates lane hp13 5da
# 522091     3 park view crescent coates lane hp13 5da
# 662822     6 park view crescent coates lane hp13 5da
# ...

# %%
LR_combined.head(n=100).to_csv('sample_lr.csv')

# %%
LR_combined['combined_address'].unique
# Out:
# <bound method Series.unique of 0                 AMERSHAM ROAD HP AA
# 1                 AMERSHAM ROAD HP AA
# 2                 AMERSHAM ROAD HP AA
# 3                 AMERSHAM ROAD HP AB
# 4                 AMERSHAM ROAD HP AD
#                      ...
# 22344    GLENTORP HALFACRE HILL SL UD
# 22345              LINDEN DRIVE SL UP
# 22346              LINDEN DRIVE SL UP
# 22347              LINDEN DRIVE SL UP
# 22348              LINDEN DRIVE SL UP
# Name: combined_address, Length: 22349, dtype: object>

# %%
valid_EPC['combined_address'].unique
# Out:
# <bound method Series.unique of 144134                                   Stanhope Road SL JS
# 144135                  Flat West Central a Stoke Road SL PF
# 144136                         a Hencroft Street South SL RF
# 144137                                       Thorndike SL SR
# 144138                                    Elmwood Road SL QQ
#                                  ...
# 1303430        High Trees Shire Lane Chalfont St Peter SL QY
# 1304184                     Nathans Barn Chalfont Road HP BT
# 1308069    Crooked Billet Shire Lane Chalfont St Peter SL QY
# 1315613     Court Cottage Shire Lane Chalfont St Peter SL RB
# 1329331                      Flat Hill View Shire Lane SL QY
# Name: combined_address, Length: 222359, dtype: object>
