# %%
import pandas as pd

# %%
merged = pd.read_csv('data_output/merged_unclean.csv')
merged.head()
# Out:
#    Unnamed: 0                             unique_id  price_paid   deed_date  \
# 0           0  E2D14905-119C-4C2D-E053-6B04A8C0422B      582000  2022-06-06
# 1           1  E2D14905-119C-4C2D-E053-6B04A8C0422B      582000  2022-06-06
# 2           2  E2D14905-119C-4C2D-E053-6B04A8C0422B      582000  2022-06-06
# 3           3  E2D14905-119C-4C2D-E053-6B04A8C0422B      582000  2022-06-06
# 4           4  2ACACE8C-96D3-295E-E063-4804A8C0B0EB      655000  2024-12-12
#
#    postcode property_type new_build estate_type saon paon  ...  \
# 0  HP13 5AA             S         N           F  NaN   49  ...
# 1  HP13 5AA             S         N           F  NaN   49  ...
# 2  HP13 5AA             S         N           F  NaN   49  ...
# 3  HP13 5AA             S         N           F  NaN   49  ...
# 4  HP13 5AA             S         N           F  NaN   67  ...
#
#     LODGEMENT_DATETIME          TENURE FIXED_LIGHTING_OUTLETS_COUNT  \
# ...

# %%
col = '_merge'
print(merged[col])
# Out:
# 0        both
# 1        both
# 2        both
# 3        both
# 4        both
#          ...
# 31015    both
# 31016    both
# 31017    both
# 31018    both
# 31019    both
# Name: _merge, Length: 31020, dtype: object

# %%
merged[col].value_counts()
# Out:
# _merge
# both         29168
# left_only     1852
# Name: count, dtype: int64

# %%
drop_cols = ['Unnamed: 0', 'unique_id']
