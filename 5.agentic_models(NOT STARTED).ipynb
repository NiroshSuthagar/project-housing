# %% [markdown]
# # Baseline Naive Agent

# %% [markdown]
# # Agentic Models

# %% [markdown]
# 1. Naive Agent (Baseline)

# %% [markdown]
# ## 2. Multi-Agent Model

# %% [markdown]
# ## 3. Baseline Naive Agent With RAG

# %% [markdown]
# ## 4. Multi-Agent Model With RAG
